# %% [markdown]
# <a href="https://colab.research.google.com/github/FiII04/QLC240_rng/blob/main/Excercise2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris

# %% [markdown]
# Add a text box below to describe what you are doing in the following cell.
# Example:
# Importing the following packages needed to plot etc....
#
# - Packages likely to need:
#   - numpy as np
#   - pandas as pd
#   - matplotlib.pyplot as plt
#   - seaborn as sns
#   - from sklearn.datasets import load_iris

# %%
iris = load_iris()

# %%
#Create a cell that imports the data "iris_df.txt" into a pandas dataframe? Use the Pandas package (see information on Pandas on google) and save into a variable called iris_fromdata

# %%
iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)

# %%
iris_df['species'] = iris.target

# %%
iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %% [markdown]
# Plot the data!

# %% [markdown]
# 1. Plot iris_df as a histogram

# %%
# prompt: iris.df.hist(figsize=(10, 6)

import matplotlib.pyplot as plt
iris_df.hist(figsize=(10, 6))
plt.show()

# %% [markdown]
# 2. Plot iris_df as a pair plot in seaborn

# %%
sns.pairplot(iris_df, hue='species' )
plt.show()

# %% [markdown]
# 4. Plot iris_df as a scatter plot using seaborn

# %%
# prompt: sns.scatterplot(data=iris_df, x='sepal length (cm)' , y= 'sepal width (cm)', hue= 'species')

import matplotlib.pyplot as plt
# Add target variable to the dataframe
iris_df['species'] = iris.target_names[iris.target]

sns.scatterplot(data=iris_df, x='sepal length (cm)', y='sepal width (cm)', hue='species')
plt.show()

# %% [markdown]
# Add a text box below and answer the following:
# 1. The pair plot 2 plots above this cell, is showing what? What is a sepal and a petal?
# 2. What is the figure above showing? What does this figure show about the relationship between sepal length and sepal width?
# 3. What is it showing about the species?
# 4. If you'd like to train a model on this data, what would you like to try and predict?

# %% [markdown]
# 1. The pair plot is showing a correlation between petal width and length and sepal width and length. Sepals are the outer, leaf-like parts of a flower that protect the bud. Petals are the often colorful, inner parts that attract pollinators.
# 2. The figure above is showing the correlation between sepal length and width of different species of flower. It shows a positive correlation between sepal length and width for all three species.
# 3. It's showing that the setosa spicies have the strongest correlation, lowest average length and biggest average width out of all the spicies. Versicolor spicies have medium correlation, medium average length and lowest average width. Virginica spicies have medium correlation, highest average length, and medium average width.
# 4. When training a model on this data, based on length and width we would try to predict which species it is.

# %%
#Add a title to the figure below

# %%
# Add target variable to the dataframe
iris_df['species'] = iris.target_names[iris.target]
sns.scatterplot(data=iris_df, x='sepal length (cm)', y='sepal width (cm)', hue='species')
#Add a title to the figure below
plt.title('Sepal Length vs Sepal Width')
plt.show()

# %%
#Change the font of the x and y axis labels, to 10

# %%
# Add target variable to the dataframe
iris_df['species'] = iris.target_names[iris.target]
sns.scatterplot(data=iris_df, x='sepal length (cm)', y='sepal width (cm)', hue='species')
#Change the font of the x and y axis labels, to 10
plt.title('Sepal Length vs Sepal Width')
plt.xlabel('Sepal Length (cm)', fontsize=10)
plt.ylabel('Sepal Width (cm)', fontsize=10)
plt.show()

# %%
#move the legend to the lower right hand region

# %%
# Add target variable to the dataframe
iris_df['species'] = iris.target_names[iris.target]
sns.scatterplot(data=iris_df, x='sepal length (cm)', y='sepal width (cm)', hue='species')
#move the legend to the lower right hand region
plt.title('Sepal Length vs Sepal Width')
plt.xlabel('Sepal Length (cm)', fontsize=10)
plt.ylabel('Sepal Width (cm)', fontsize=10)
plt.legend(loc='lower right')
plt.show()

# %%
# Change the following plot to only plot the setosa species

# %%
# Add target variable to the dataframe
iris_df['species'] = iris.target_names[iris.target]
# sns.scatterplot(data=iris_df, x='sepal length (cm)', y='sepal width (cm)', hue='species')
# Change the following plot to only plot the setosa species
setosa_df = iris_df[iris_df['species'] == 'setosa']
sns.scatterplot(data=setosa_df, x='sepal length (cm)', y='sepal width (cm)', hue='species')
#
# Out:
# <Axes: xlabel='sepal length (cm)', ylabel='sepal width (cm)'>

# %% [markdown]
# *Why* might filtering data be useful?

# %%
# prompt: Why might filtering data be useful? Explain in 40 words, use comprehensive language

# Filtering isolates specific data subsets, enabling focused analysis, model training on relevant data, and clearer visualizations by removing irrelevant information.
